# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import gym
import gym_minigrid
import matplotlib.pyplot as plt

# %%
env = gym.make('MiniGrid-Empty-5x5-v0')
env.reset()
before_img = env.render('rgb_array')
action = env.actions.forward
obs, reward, done, info = env.step(action)
after_img = env.render('rgb_array')

plt.imshow(np.concatenate([before_img, after_img], 1));

# %%
import os
print(os.getcwd())
# Out:
# /export/home/cuda00031/showalter/cameleon

# %%
from cameleon.envs.large_dynamic_obstacles import *

# %%
env = gym.make('MiniGrid-Dynamic-Obstacles-100x100-v0')
env.reset()
before_img = env.render('rgb_array')
action = env.actions.forward
obs, reward, done, info = env.step(action)
after_img = env.render('rgb_array')

plt.imshow(np.concatenate([before_img, after_img], 1));
